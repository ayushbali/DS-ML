# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Picking the right model for the problem in hand
# - Models/Estimator/algorithm are used hand in hand
# - Types of Problem:
#     - Classification
#     - Regression

# %%
# get california housing dataset
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()

type(housing) # <class 'sklearn.utils.Bunch'>
# print(housing)

# convert to pandas dataframe
import pandas as pd

# I have used a dot notation and as well as a square breacket notation to access the feature names. Both are valid ways to access the data in the housing dataset. 

housing_df = pd.DataFrame(housing.data, columns=housing['feature_names'])
housing_df
housing_df['Target'] = housing.target
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  ...  AveOccup  Latitude  Longitude  Target
# 0  8.3252      41.0  6.984127   1.023810  ...  2.555556     37.88    -122.23   4.526
# 1  8.3014      21.0  6.238137   0.971880  ...  2.109842     37.86    -122.22   3.585
# 2  7.2574      52.0  8.288136   1.073446  ...  2.802260     37.85    -122.24   3.521
# 3  5.6431      52.0  5.817352   1.073059  ...  2.547945     37.85    -122.25   3.413
# 4  3.8462      52.0  6.281853   1.081081  ...  2.181467     37.85    -122.25   3.422
#
# [5 rows x 9 columns]

# %%
# Explore the data
housing_df.info()
# Non Null count
housing_df.isna().sum()
# describe the data
housing_df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Target      20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
#              MedInc      HouseAge  ...     Longitude        Target
# count  20640.000000  20640.000000  ...  20640.000000  20640.000000
# mean       3.870671     28.639486  ...   -119.569704      2.068558
# std        1.899822     12.585558  ...      2.003532      1.153956
# min        0.499900      1.000000  ...   -124.350000      0.149990
# ...

# %%
# Importing Algorithm
from sklearn.model_selection import train_test_split

# Random Seed
np.random.seed(42)

# Create Data for train and test
X = housing_df.drop('Target', axis=1)
y = housing_df['Target']

X.shape, y.shape

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  ...  AveOccup  Latitude  Longitude  Target
# 0  8.3252      41.0  6.984127   1.023810  ...  2.555556     37.88    -122.23   4.526
# 1  8.3014      21.0  6.238137   0.971880  ...  2.109842     37.86    -122.22   3.585
# 2  7.2574      52.0  8.288136   1.073446  ...  2.802260     37.85    -122.24   3.521
# 3  5.6431      52.0  5.817352   1.073059  ...  2.547945     37.85    -122.25   3.413
# 4  3.8462      52.0  6.281853   1.081081  ...  2.181467     37.85    -122.25   3.422
#
# [5 rows x 9 columns]

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3, figsize=(10, 10))

x1 = housing_df['MedInc']
x2 = housing_df['HouseAge']
x3 = housing_df['AveRooms']
x4 = housing_df['AveBedrms']
x5 = housing_df['Population']
x6 = housing_df['AveOccup']

y = housing_df['Target']

ax1.bar(x1, x3 )
ax1.set(xlabel='MedInc', ylabel='Avg Rooms', title='MedInc vs Avg Rooms')

ax2.bar(x2, x4)
ax2.set(xlabel='HouseAge', ylabel='Avg Bedrms', title='HouseAge vs Avg Bedrms')

ax3.bar(x3, x5)
ax3.set(xlabel='AveRooms', ylabel='Population', title='AveRooms vs Population')

ax4.bar(x4, x6)
ax4.set(xlabel='AveBedrms', ylabel='AveOccup', title='AveBedrms vs AveOccup')

ax5.bar(x5, y)
ax5.set(xlabel='Population', ylabel='Target', title='Population vs Target')

ax6.bar(x6, y)
ax6.set(xlabel='AveOccup', ylabel='Target', title='AveOccup vs Target')
# Out:
# [Text(0.5, 0, 'AveOccup'),
#  Text(0, 0.5, 'Target'),
#  Text(0.5, 1.0, 'AveOccup vs Target')]

# %% [markdown]
# ### Ridge Regression

# %%
# Ridge Regression Model

from sklearn.linear_model import Ridge

np.random.seed(42)

X = housing_df.drop('Target', axis=1)
y = housing_df['Target']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

model = Ridge()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.5758549611440126

# %% [markdown]
# ### Random Forest Regressor

# %%
# Random Forest Regressor 
from sklearn.ensemble import RandomForestRegressor

np.random.seed(42)

X = housing_df.drop('Target', axis=1)
y = housing_df['Target']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8060350564103272

# %% [markdown]
# ## Choosing a model for a Classification problem

# %%
heart_disease = pd.read_csv('./data/heart-disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Import LinearSVC from sklearn
from sklearn.svm import LinearSVC

# Define the random seed
np.random.seed(42)

# define X and y
X = heart_disease.drop('target', axis=1)
y = heart_disease['target']

print(y.value_counts())

X.shape, y.shape

# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Initialize the model
model = LinearSVC()
# Fit the model to the training data
model.fit(X_train, y_train)
# Evaluate the model on the test data
model.score(X_test, y_test)
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64
# 0.8688524590163934
